# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
def bar_plot(ypos,Year_data,a):
    fig = plt.figure(figsize=(10, 5))
    plt.xticks(ypos,Countries_data)
    return plt.bar(ypos,Year_data, width = a)

# %%
newdata = pd.read_excel("Mobile Cellular Subscription 2015- Copy.xlsx")
Countries_data = newdata.Countries
Year_data = newdata.Year2015
ypos = np.arange(len(Countries_data))
bar_plot(ypos,Year_data,0.5)
plt.show()

# %%
newdata.Countries
# Out:
# 0    Afghanistan
# 1     Bangladesh
# 2         Bhutan
# 3          India
# 4       Maldives
# 5          Nepal
# 6       Pakistan
# 7       SriLanka
# Name: Countries, dtype: object
