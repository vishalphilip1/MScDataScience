# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data1 = pd.read_excel("Mobile cellular subscriptions.xlsx")
data1
# Out:
#     Year   Afghanistan     Bangladesh     Bhutan            India   Maldives  \
# 0   2005   1,200,000.0    9,000,000.0   36,000.0     90,140,000.0  203,620.0
# 1   2006   2,520,366.0   19,130,983.0   82,078.0    166,050,000.0  271,053.0
# 2   2007   4,668,096.0   34,370,000.0  149,439.0    233,620,000.0  313,539.0
# 3   2008   7,898,909.0   44,640,000.0  253,429.0    346,890,000.0  435,627.0
# 4   2009  10,500,000.0   51,359,315.0  338,938.0    525,090,000.0  457,770.0
# 5   2010  10,215,840.0   67,923,887.0  394,316.0    752,190,000.0  494,351.0
# 6   2011  13,797,879.0   84,368,700.0  484,189.0    893,862,478.0  530,449.0
# 7   2012  15,340,115.0   97,180,000.0  560,890.0    864,720,917.0  560,547.0
# 8   2013  16,807,156.0  116,553,076.0  544,337.0    886,304,245.0  625,161.0
# 9   2014  18,407,168.0  126,866,091.0  624,536.0    944,008,677.0  665,818.0
# 10  2015  19,709,038.0  131,375,724.0  675,747.0  1,001,056,000.0  739,790.0
#
# ...

# %%
def line_p(x_axis, y_axis,name,col):
    plt.plot(x_axis,y_axis,label= name, color= col))
    #plt.xlim(2005, 2015)
    #plt.yscale('log')

# %%
plt.figure()

""""line_p(data1.Year , data1.India)
line_p(data1.Year , data1.Afghanistan)
line_p(data1.Year , data1.Bangladesh)
#line_p(data1.Year , data1.Bhutan)
line_p(data1.Year , data1.Maldives) """
line_p(data1.Year , data1.Nepal,"Nepal","Red")
#line_p(data1.Year , data1.Pakistan)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8480\3903911089.py in <module>
#       6 #line_p(data1.Year , data1.Bhutan)
#       7 line_p(data1.Year , data1.Maldives) """
# ----> 8 line_p(data1.Year , data1.Nepal,"Nepal","Red")
#       9 #line_p(data1.Year , data1.Pakistan)
#      10
#
# TypeError: line_p() takes 2 positional arguments but 4 were given

# %%
print(data1.columns)
# Out:
# Index(['Year', 'Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Maldives',
#        'Nepal', 'Pakistan', 'Sri Lanka'],
#       dtype='object')
