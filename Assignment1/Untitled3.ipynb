# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
def plot_pie(Pie_Data,Pie_label):
    return plt.pie(Pie_Data, labels = Pie_label,autopct='%1.1f%%' )

# %%
pie_data = pd.read_excel("ForestArea.xlsx")
Countries_name = pie_data.Countries
Forest_Data = pie_data.Year_2015
plot_pie(Forest_Data, Countries_name)
plt.show()

# %%
Countries_name = pie_data.Countries
Forest_Data = pie_data.Year_2015

# %%
plt.pie(Forest_Data, labels=Countries_name,autopct='%1.1f%%')
plt.show()
