# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statistics

# %%
df1= pd.read_excel("Mobile Cellular Subscription per 100.xlsx")

# %%
df1
# Out:
#                                                       2000  2001  2002  2003  \
# 0                                        Afghanistan   0.0   0.0   0.1   0.9
# 1                                         Bangladesh   0.2   0.4   0.8   1.0
# 2                                             Bhutan   0.0   0.0   0.0   0.4
# 3                                              India   0.3   0.6   1.2   3.0
# 4                                           Maldives   2.7   6.6  14.3  22.4
# 5                                              Nepal   0.0   0.1   0.1   0.3
# 6                                           Pakistan   0.2   0.5   1.0   1.4
# 7                                          Sri Lanka   2.3   3.5   4.9   7.2
# 8  Created from: World Development Indicators\nSe...   NaN   NaN   NaN   NaN
#
#    2004  2005  2006  2007   2008   2009  Unnamed: 11   2010   2011   2012  \
# 0   2.5   4.9   9.9  18.0   29.9   38.3          NaN   36.2   47.2   50.4
# ...

# %%
df2 = df1.drop(8)

# %%
df3 = df2.drop( columns =['2000' , '2001', '2002', '2003','2004','Unnamed: 11' ])

# %%
df3

# %%
means = df3.mean(axis=1)

# %%
print("means \n" ,means)

# %%
medians = df3.median(axis=1)
print("medians \n" , medians)

# %%
stds = df3.std(axis=1)
print("Standard Deviation \n" , stds)

# %%
def line(x_axis, y_axis, name, col):
    plt.plot(x_axis,y_axis, '.-',label= name, color= col)
